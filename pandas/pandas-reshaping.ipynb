# %% [markdown]
# ## pivot_table

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({
    "A": ["aaa", "aaa", "aaa", "aaa", "aaa", "ccc", "ccc", "ccc", "ccc"],
    "B": ["xxx", "xxx", "xxx", "yyy", "yyy", "xxx", "xxx", "yyy", "yyy"],
    "C": [
        "small", "LARGE", "LARGE", "small", "small", "LARGE", "small", "small",
        "LARGE"
    ],
    "D": [1, 2, 2, 3, 3, 4, 5, 6, 7],
    "E": [2, 4, 5, 5, 6, 6, 8, 9, 9]
})

# %%
df
# Out:
#      A    B      C  D  E
# 0  aaa  xxx  small  1  2
# 1  aaa  xxx  LARGE  2  4
# 2  aaa  xxx  LARGE  2  5
# 3  aaa  yyy  small  3  5
# 4  aaa  yyy  small  3  6
# 5  ccc  xxx  LARGE  4  6
# 6  ccc  xxx  small  5  8
# 7  ccc  yyy  small  6  9
# 8  ccc  yyy  LARGE  7  9

# %%
pd.pivot_table(df, values='D', index=['A', 'B'],
               columns=['C'], aggfunc=np.sum)
# Out:
# C        LARGE  small
# A   B
# aaa xxx    4.0    1.0
#     yyy    NaN    6.0
# ccc xxx    4.0    5.0
#     yyy    7.0    6.0

# %%
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'], aggfunc=np.sum, fill_value=0)
# Out:
# C        LARGE  small
# A   B
# aaa xxx      4      1
#     yyy      0      6
# ccc xxx      4      5
#     yyy      7      6

# %%
pd.pivot_table(df, values=['D', 'E'], index=['A', 'C'],
            aggfunc={'D': [np.mean,np.min],
                     'E': [np.mean,np.max]})
# Out:
#              D              E
#           amin      mean amax      mean
# A   C
# aaa LARGE  2.0  2.000000  5.0  4.500000
#     small  1.0  2.333333  6.0  4.333333
# ccc LARGE  4.0  5.500000  9.0  7.500000
#     small  5.0  5.500000  9.0  8.500000

# %%
pd.pivot_table(df, values=['D', 'E'], index=['A', 'C'],
               aggfunc={'D': np.mean,
                        'E': [np.min, np.max, np.mean]})
# Out:
#                   D    E
#                mean amax amin      mean
# A   C
# aaa LARGE  2.000000  5.0  4.0  4.500000
#     small  2.333333  6.0  2.0  4.333333
# ccc LARGE  5.500000  9.0  6.0  7.500000
#     small  5.500000  9.0  8.0  8.500000

# %% [markdown]
# ## pivot

# %%
df = pd.DataFrame({'foo': ['one', 'one', 'one', 'two', 'two',
                           'two'],
                   'bar': ['A', 'B', 'C', 'A', 'B', 'C'],
                   'baz': [1, 2, 3, 4, 5, 6],
                   'zoo': ['x', 'y', 'z', 'q', 'w', 't']})
df
# Out:
#    foo bar  baz zoo
# 0  one   A    1   x
# 1  one   B    2   y
# 2  one   C    3   z
# 3  two   A    4   q
# 4  two   B    5   w
# 5  two   C    6   t

# %%
df.pivot(index='foo', columns='bar', values='baz')
# Out:
# bar  A  B  C
# foo
# one  1  2  3
# two  4  5  6

# %%
df.pivot(index='foo', columns='bar')
# Out:
#     baz       zoo
# bar   A  B  C   A  B  C
# foo
# one   1  2  3   x  y  z
# two   4  5  6   q  w  t

# %%
df.pivot(index='foo', columns='bar')['baz']
# Out:
# bar  A  B  C
# foo
# one  1  2  3
# two  4  5  6

# %%
# 如果有重复的值则会报错：

df = pd.DataFrame({"foo": ['one', 'one', 'two', 'two'],
                   "bar": ['A', 'A', 'B', 'C'],
                   "baz": [1, 2, 3, 4]})
df
# Out:
#    foo bar  baz
# 0  one   A    1
# 1  one   A    2
# 2  two   B    3
# 3  two   C    4

# %%
df.pivot(index='foo', columns='bar', values='baz')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-2f9eca6fee6a> in <module>
# ----> 1 df.pivot(index='foo', columns='bar', values='baz')
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    5626     def pivot(self, index=None, columns=None, values=None):
#    5627         from pandas.core.reshape.pivot import pivot
# -> 5628         return pivot(self, index=index, columns=columns, values=values)
#    5629
#    5630     _shared_docs['pivot_table'] = """
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/reshape/pivot.py in pivot(data, index, columns, values)
#     386             indexed = data._constructor_sliced(data[values].values,
#     387                                                index=index)
# --> 388     return indexed.unstack(columns)
#     389
#     390
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/series.py in unstack(self, level, fill_value)
#    3299         """
#    3300         from pandas.core.reshape.reshape import unstack
# -> 3301         return unstack(self, level, fill_value)
#    3302
#    3303     # ----------------------------------------------------------------------
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/reshape/reshape.py in unstack(obj, level, fill_value)
#     394         unstacker = _Unstacker(obj.values, obj.index, level=level,
#     395                                fill_value=fill_value,
# --> 396                                constructor=obj._constructor_expanddim)
#     397         return unstacker.get_result()
#     398
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/reshape/reshape.py in __init__(self, values, index, level, value_columns, fill_value, constructor)
#     126
#     127         self._make_sorted_values_labels()
# --> 128         self._make_selectors()
#     129
#     130     def _make_sorted_values_labels(self):
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/reshape/reshape.py in _make_selectors(self)
#     164
#     165         if mask.sum() < len(self.index):
# --> 166             raise ValueError('Index contains duplicate entries, '
#     167                              'cannot reshape')
#     168
#
# ValueError: Index contains duplicate entries, cannot reshape

# %% [markdown]
# ## stack & unstack

# %%
data = pd.DataFrame(np.random.randn(9,2), columns=['num1','num2'],
                    index=[['a', 'a', 'a', 'b', 'b', 'c', 'c', 'd', 'd'],[1, 2, 3, 1, 3, 1, 2, 2, 3]])
data
# Out:
#          num1      num2
# a 1 -0.205420  0.380133
#   2  0.441859 -0.442451
#   3 -1.035527  1.824973
# b 1  1.066176  0.067806
#   3 -0.842479  0.969839
# c 1  0.032590  0.356842
#   2 -1.217016  0.328401
# d 2 -0.062957  1.879494
#   3  0.547132 -0.992702

# %%
data.unstack()
# Out:
#        num1                          num2
#           1         2         3         1         2         3
# a -0.205420  0.441859 -1.035527  0.380133 -0.442451  1.824973
# b  1.066176       NaN -0.842479  0.067806       NaN  0.969839
# c  0.032590 -1.217016       NaN  0.356842  0.328401       NaN
# d       NaN -0.062957  0.547132       NaN  1.879494 -0.992702

# %%
data.unstack(level=0).stack()
# Out:
#          num1      num2
# 1 a -0.205420  0.380133
#   b  1.066176  0.067806
#   c  0.032590  0.356842
# 2 a  0.441859 -0.442451
#   c -1.217016  0.328401
#   d -0.062957  1.879494
# 3 a -1.035527  1.824973
#   b -0.842479  0.969839
#   d  0.547132 -0.992702

# %%
frame = pd.DataFrame(np.arange(12).reshape((4, 3)),
                     index=[['a', 'a', 'b', 'b'], [1, 2, 1, 2]],
                     columns=[['Ohio', 'Ohio', 'Colorado'],
                              ['Green', 'Red', 'Green']])
frame
# Out:
#      Ohio     Colorado
#     Green Red    Green
# a 1     0   1        2
#   2     3   4        5
# b 1     6   7        8
#   2     9  10       11

# %%
frame.index.names = ['key1', 'key2']
frame.columns.names = ['state', 'color']
frame
# Out:
# state      Ohio     Colorado
# color     Green Red    Green
# key1 key2
# a    1        0   1        2
#      2        3   4        5
# b    1        6   7        8
#      2        9  10       11

# %%
frame.unstack()
# Out:
# state  Ohio            Colorado
# color Green    Red        Green
# key2      1  2   1   2        1   2
# key1
# a         0  3   1   4        2   5
# b         6  9   7  10        8  11

# %%
frame.unstack().unstack()
# Out:
# state     color  key2  key1
# Ohio      Green  1     a        0
#                        b        6
#                  2     a        3
#                        b        9
#           Red    1     a        1
#                        b        7
#                  2     a        4
#                        b       10
# Colorado  Green  1     a        2
#                        b        8
#                  2     a        5
#                        b       11
# dtype: int64

# %%
frame.unstack().stack()
# Out:
# state     Colorado  Ohio
# color        Green Green Red
# key1 key2
# a    1           2     0   1
#      2           5     3   4
# b    1           8     6   7
#      2          11     9  10

# %%
frame.index.names = [None,None]
frame.columns.names = [None,None]
frame
# Out:
#      Ohio     Colorado
#     Green Red    Green
# a 1     0   1        2
#   2     3   4        5
# b 1     6   7        8
#   2     9  10       11

# %%
frame.stack(level=1)
# Out:
#            Colorado  Ohio
# a 1 Green       2.0     0
#     Red         NaN     1
#   2 Green       5.0     3
#     Red         NaN     4
# b 1 Green       8.0     6
#     Red         NaN     7
#   2 Green      11.0     9
#     Red         NaN    10

# %%
frame.stack(level=1).stack()
# Out:
# a  1  Green  Colorado     2.0
#              Ohio         0.0
#       Red    Ohio         1.0
#    2  Green  Colorado     5.0
#              Ohio         3.0
#       Red    Ohio         4.0
# b  1  Green  Colorado     8.0
#              Ohio         6.0
#       Red    Ohio         7.0
#    2  Green  Colorado    11.0
#              Ohio         9.0
#       Red    Ohio        10.0
# dtype: float64

# %%
frame1 = frame.stack(level=1).reset_index()
frame1
# Out:
#   level_0  level_1 level_2  Colorado  Ohio
# 0       a        1   Green       2.0     0
# 1       a        1     Red       NaN     1
# 2       a        2   Green       5.0     3
# 3       a        2     Red       NaN     4
# 4       b        1   Green       8.0     6
# 5       b        1     Red       NaN     7
# 6       b        2   Green      11.0     9
# 7       b        2     Red       NaN    10

# %%
pd.pivot_table(frame1, index=['level_0','level_1'],columns=['level_2'])
# Out:
#                 Colorado  Ohio
# level_2            Green Green Red
# level_0 level_1
# a       1            2.0     0   1
#         2            5.0     3   4
# b       1            8.0     6   7
#         2           11.0     9  10

# %%
pd.pivot_table(frame1, index=['level_0','level_1','level_2'])
# Out:
#                          Colorado  Ohio
# level_0 level_1 level_2
# a       1       Green         2.0     0
#                 Red           NaN     1
#         2       Green         5.0     3
#                 Red           NaN     4
# b       1       Green         8.0     6
#                 Red           NaN     7
#         2       Green        11.0     9
#                 Red           NaN    10
