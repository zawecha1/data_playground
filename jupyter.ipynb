# %%
import numpy as np
import pandas as pd 
arr = np.random.rand(5,6)
df = pd.DataFrame(arr)
df.head()
# Out:
#           0         1         2         3         4         5
# 0  0.722819  0.285847  0.872894  0.960798  0.122004  0.748457
# 1  0.218883  0.470699  0.074077  0.715776  0.921802  0.379339
# 2  0.504457  0.325394  0.076280  0.071903  0.958009  0.235286
# 3  0.494355  0.842700  0.479744  0.395637  0.067415  0.608959
# 4  0.279040  0.701776  0.902219  0.743789  0.125935  0.053441

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
# 0    5 non-null float64
# 1    5 non-null float64
# 2    5 non-null float64
# 3    5 non-null float64
# 4    5 non-null float64
# 5    5 non-null float64
# dtypes: float64(6)
# memory usage: 320.0 bytes

# %%
# %quickref

# %%
# %magic

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
# %%time 

import time
import numpy as np

def time_test():
    arr = np.random.rand(5,6)
    for i in range(10000):
        arr += (-1)**i
    return arr

# %lprun time_test()
# Out:
# UsageError: Line magic function `%lprun` not found.

# %%
# %time time_test()
# Out:
# CPU times: user 24.9 ms, sys: 712 µs, total: 25.6 ms
# Wall time: 25.8 ms
# array([[0.18327116, 0.96444438, 0.04454326, 0.12648767, 0.25893511,
#         0.76808734],
#        [0.62344477, 0.53065698, 0.34743636, 0.89130939, 0.68630772,
#         0.80628819],
#        [0.54831486, 0.93511942, 0.28615647, 0.57993684, 0.52854378,
#         0.24556386],
#        [0.64623285, 0.08668083, 0.46366105, 0.71258623, 0.34103811,
#         0.78762144],
#        [0.24053686, 0.2459879 , 0.59413691, 0.2871902 , 0.4316815 ,
#         0.29592306]])

# %%
# %timeit time_test()
# Out:
# 17.7 ms ± 312 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %who_ls
# Out:
# ['a', 'np', 'time', 'time_test']

# %%
# %who_ls function
# Out:
# ['time_test']

# %%
# %system date
# Out:
# ['Tue Jan 15 00:47:38 CST 2019']

# %%
# !date
# Out:
# Tue Jan 15 00:48:17 CST 2019

# %%
# !!date
# Out:
# ['Tue Jan 15 00:48:24 CST 2019']

# %%
# %env
# Out:
# {'TERM_PROGRAM': 'iTerm.app',
#  'TERM': 'xterm-color',
#  'SHELL': '/bin/bash',
#  'TMPDIR': '/var/folders/9q/3mxkdpqs6kl4_sh3qcsjkz_w0000gn/T/',
#  'CONDA_SHLVL': '0',
#  'Apple_PubSub_Socket_Render': '/private/tmp/com.apple.launchd.3NcjyUzGmy/Render',
#  'TERM_PROGRAM_VERSION': '3.1.7',
#  'OLDPWD': '/Users/zhangqibot/myspace/script/mygit/MeteoAI',
#  'TERM_SESSION_ID': 'w0t0p0:82D64000-3C43-4B03-9DEF-F3175FBB9E4F',
#  'USER': 'zhangqibot',
#  'SSH_AUTH_SOCK': '/private/tmp/com.apple.launchd.cNdFvbrAT3/Listeners',
#  '__CF_USER_TEXT_ENCODING': '0x0:25:52',
#  'PATH': '/Users/zhangqibot/miniconda3/bin:/Users/zhangqibot/miniconda3/bin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/Applications/Visual Studio Code.app/Contents/Resources/app/bin',
#  'PWD': '/Users/zhangqibot/myspace/script/mygit/MeteoAI/meteo_data_analysis_basic',
#  'ITERM_PROFILE': 'Default',
#  'XPC_FLAGS': '0x0',
#  'XPC_SERVICE_NAME': '0',
#  'SHLVL': '1',
#  'HOME': '/Users/zhangqibot',
#  'COLORFGBG': '7;0',
# ...

# %%
# %whos
# Out:
# Variable    Type        Data/Info
# ---------------------------------
# np          module      <module 'numpy' from '/Us<...>kages/numpy/__init__.py'>
# time        module      <module 'time' (built-in)>
# time_test   function    <function time_test at 0x10f433620>

# %%
# %%markdown
# ## a
# Out:
# ## a

# %%
# !pip install https://github.com/ipython-contrib/jupyter_contrib_nbextensions/tarball/master
# !pip install jupyter_nbextensions_configurator
# !jupyter contrib nbextension install --user
# !jupyter nbextensions_configurator enable --user
# Out:
# ...
#      \ 25.0MB 506kB/s/s
# ...
#     100% |████████████████████████████████| 870kB 176kB/s ta 0:00:011
# ...
#     100% |████████████████████████████████| 481kB 127kB/s ta 0:00:011
# ...
#     100% |████████████████████████████████| 276kB 182kB/s ta 0:00:01
# ...
#   Running setup.py bdist_wheel for jupyter-contrib-nbextensions ... done
#   Stored in directory: /private/var/folders/9q/3mxkdpqs6kl4_sh3qcsjkz_w0000gn/T/pip-ephem-wheel-cache-hku06pn5/wheels/22/4a/9f/df59e985684a10ea0e025300581870b5b3a300ee3525f0eef5
#   Running setup.py bdist_wheel for jupyter-latex-envs ... done
#   Stored in directory: /Users/zhangqibot/Library/Caches/pip/wheels/0d/71/2a/164491997299b9f2479a251e254323fe35d946779e18f27956
#   Running setup.py bdist_wheel for jupyter-nbextensions-configurator ... done
#   Stored in directory: /Users/zhangqibot/Library/Caches/pip/wheels/15/df/fe/2a74fe34709e7fdc5ae153a768675d9fda93cc7d5133ed1fb0
#   Running setup.py bdist_wheel for pyyaml ... done
# ...

# %%
np.random.rand??

# %%
np.concatenate?

# %%
list??

# %%
from IPython.display import IFrame
IFrame('https://www.baidu.com', width=800, height=450)
# Out:
#         <iframe
#             width="800"
#             height="450"
#             src="https://www.baidu.com"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
from IPython.display import IFrame
IFrame('https://www.cs.uky.edu/~keen/115/Haltermanpythonbook.pdf', width=800, height=450)
# Out:
#         <iframe
#             width="800"
#             height="450"
#             src="https://www.cs.uky.edu/~keen/115/Haltermanpythonbook.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('mJeNghZXtMo', width=800, height=300)
# Out:
#         <iframe
#             width="800"
#             height="300"
#             src="https://www.youtube.com/embed/mJeNghZXtMo"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
